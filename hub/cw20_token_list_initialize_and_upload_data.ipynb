# %% [markdown]
# # initialize and upload cw20 token list into a hub-like contract
# `cw20 token list` contract is experimental and is not a part of hub.

# %%
import pandas as pd
from warnings import filterwarnings
from tqdm.notebook import tqdm
import json
from ipfshttpclient import Client
from multiaddr import Multiaddr
from typing import Optional, Union
from re import sub

from cyber_sdk.client.lcd import LCDClient
from cyber_sdk.client.lcd.wallet import Wallet
from cyber_sdk.core import AccAddress
from cyber_sdk.key.mnemonic import MnemonicKey
from cyberutils.bash import get_json_from_bash_query
from cyberutils.contract import execute_contract

from ..src.contract_utils import query_contract, instantiate_contract
from ..config import NODE_RPC_URL, LCD_CLIENT, WALLET_SEED, IPFS_HOST

filterwarnings('ignore')

# %%
ipfs_client = Client(Multiaddr(IPFS_HOST))
mk = MnemonicKey(mnemonic=WALLET_SEED)
WALLET = LCD_CLIENT.wallet(mk)
WALLET_ADDRESS = WALLET.key.acc_address
INIT_CONTRACT = False
contract_address = 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3'

# %% [markdown]
# ## generate data

# %%
cw20_contracts = get_json_from_bash_query(
    bash_command=f'cyber query wasm list-contract-by-code 1 -o=json --limit=1000 --node={NODE_RPC_URL}')['contracts']

# %%
cw20_json = []
for cw20_contract in tqdm(cw20_contracts):
    cw20_metadata = \
        query_contract(contract_address=cw20_contract,
                       query='''{"token_info": {}}''')['data']
    cw20_marketing_info = \
        query_contract(contract_address=cw20_contract,
                       query='''{"marketing_info": {}}''')['data']
    logo = cw20_marketing_info['logo']
    cw20_json.append(
        {
            'chain_id': 'bostrom',
            'channel_id': '',
            'contract': cw20_contract,
            'decimals': str(cw20_metadata['decimals']),
            'logo': ipfs_client.add_str('' if logo is None or logo == {'url': ''} else str(logo['url'])),
            'ticker': sub(r'\W', '', string=cw20_metadata['symbol']).upper()
        }
    )
cw20_df = pd.DataFrame(cw20_json)
cw20_df
# Out:
#   0%|          | 0/106 [00:00<?, ?it/s]
#     chain_id channel_id                                           contract  \
# 0    bostrom             bostrom14hj2tavq8fpesdwxxcu44rty3hh90vhujrvcms...
# 1    bostrom             bostrom1suhgf5svhu4usrurvxzlgn54ksxmn8gljarjtx...
# 2    bostrom             bostrom1yyca08xqdgvjz0psg56z67ejh9xms6l436u8y5...
# 3    bostrom             bostrom1yw4xvtc43me9scqfr2jr2gzvcxd3a9y4eq7gau...
# 4    bostrom             bostrom1cnuw3f076wgdyahssdkd0g3nr96ckq8cwa2mh0...
# ..       ...        ...                                                ...
# 101  bostrom             bostrom1s5g4rehkansq4pamj42usczezqkchjke4j2kk7...
# 102  bostrom             bostrom1seeld9pqq0nxp3yt3wded4jf476y8vz77qmjj5...
# 103  bostrom             bostrom10stecvwvxzkh3ah7y6j0kcwe3chmrg37zevjgj...
# 104  bostrom             bostrom1w4dff5myjyzymk8tkpjrzj6gnv352hcdpt2dsz...
# 105  bostrom             bostrom1nwm9pjmfgmxgc4euyfps05p9pfde8vd4sm8pav...
#
#     decimals                                            logo ticker
# 0          0  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH   FCWT
# 1          0  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH    NTN
# 2          0  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH    NTN
# 3          0  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH    NTN
# 4          0  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH    SKI
# ..       ...                                             ...    ...
# 101        0  Qma9xsv2iWdecCQtrkQoiXwQhd7dWvJ6175kjmjhgSKfcQ    TTT
# 102        0  QmefkBJpLP8nVZknst77mLFznRCgvn1UnSMAU1zfXgJe6d    ABC
# 103       10  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH   AAAC
# 104        6  QmRbEoWS3jPxYkb2yzHv7Sio3tr3sU1oQArmhBAGuXaVZA   WGUT
# 105        6  QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH   COOL
#
# [106 rows x 6 columns]

# %%
cw20_json = cw20_df[['chain_id', 'channel_id', 'decimals', 'logo', 'ticker', 'contract']].to_json(orient='records')
with open('data/tokens_cw20.json', 'w') as file:
    file.write(cw20_json)

# %% [markdown]
# ## initialize contract

# %%
if INIT_CONTRACT:
    contract_address = instantiate_contract(
        init_query=f'''{{"owner":"{WALLET_ADDRESS}"}}''',
        contract_code_id='19',
        contract_label='cw20 token list',
        contract_admin='bostrom1xszmhkfjs3s00z2nvtn7evqxw3dtus6yr8e4pw',
        from_address=WALLET_ADDRESS,
        display_data=True)
contract_address
# Out:
# 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3'

# %% [markdown]
# ## upload data

# %%
def hub_upload(
        tx_unsigned_file_name: str,
        items_for_upload: list[dict],
        contract_address: str,
        required_keys: list[str],
        sender: Optional[Union[str, AccAddress]] = None,
        lcd_client: LCDClient = LCD_CLIENT,
        fee_denom: str = 'boot',
        gas: int = 5_000_000,
        wallet: Optional[Wallet] = None,
        sign_and_broadcast_tx: bool = False,
        memo='add entry') -> dict:
    _execute_msgs = []
    for _item_for_upload in items_for_upload:
        assert all(_item in _item_for_upload.keys() for _item in required_keys)
        _execute_msg = {'CreateEntry': _item_for_upload}
        _execute_msgs.append(_execute_msg)
    _tx_unsigned = execute_contract(
        execute_msgs=_execute_msgs,
        contract_address=contract_address,
        sender=sender,
        wallet=wallet,
        lcd_client=lcd_client,
        fee_denom=fee_denom,
        gas=gas,
        sign_and_broadcast_tx=sign_and_broadcast_tx,
        memo=memo
    )
    with open(tx_unsigned_file_name, 'w') as _tx_unsigned_file:
        _tx_unsigned_file.write(json.dumps(_tx_unsigned.to_data()))
    return _tx_unsigned.to_data()

# %%
contract_name = 'tokens_cw20'
with open(f'data/{contract_name}.json', 'r') as file:
    data_for_upload = json.load(file)
tx_unsigned_data = hub_upload(
    tx_unsigned_file_name=f'txs/tx_{contract_name}_upload_unsigned.json',
    items_for_upload=data_for_upload[1:],
    contract_address=contract_address,
    sender=WALLET_ADDRESS,
    wallet=WALLET,
    required_keys=['chain_id', 'channel_id', 'contract', 'decimals', 'logo', 'ticker'],
    gas=24_000_000,
    sign_and_broadcast_tx=False,
    memo='upload cw20 token list'
)
tx_unsigned_data
# Out:
# {'body': {'messages': [{'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1suhgf5svhu4usrurvxzlgn54ksxmn8gljarjtxqnapv8kjnp4nrs3mewwz'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1yyca08xqdgvjz0psg56z67ejh9xms6l436u8y58m82npdqqhmmtquldtvc'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1yw4xvtc43me9scqfr2jr2gzvcxd3a9y4eq7gaukreugw2yd2f8tsa7wdwt'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SKI',
#       'contract': 'bostrom1cnuw3f076wgdyahssdkd0g3nr96ckq8cwa2mh029fn5mgf2fmcmsyjyuue'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1ltd0maxmte3xf4zshta9j5djrq9cl692ctsp9u5q0p9wss0f5lmspn0aqx'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1wl59k23zngj34l7d42y9yltask7rjlnxgccawc7ltrknp6n52fpst3kwur'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1dt3lk455ed360pna38fkhqn0p8y44qndsr77qu73ghyaz2zv4whq795aw6'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1stwdtk6ja0705v8qmtukcp4vd422p5vy4jr5wdc4qk44c57k955qpkak5a'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1nwnejwsdpqktusvh8qhxe5arsznjd5asdwutmaz9n5qcpl3dcmhsujhemd'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1n8ze4phtshhlucclf2hkrxs3u29gtyv2cc9v5ld8fu7en6838caqtqh4es'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1y6hjq8yvqzk6al4yrjl7yjkt87ujvhaq32c0qvt7627sk0j63d2qadpn77'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom16p5fm4qrpjpxd8f5wpt48fgyyd5c79q4n35fgvq7x2yks2lu8llqrx33wz'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1m4ns69zvkk2zv0946mw298tlky5ckvu08rtxggtg29p784kc5sxqrkv5pl'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1a2366fuydkz20h9q9kaxg5vqwpu8prgs6mhwn5qha3wsups0trcqugfkh6'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom19jq6mj84cnt9p7sagjxqf8hxtczwc8wlpuwe4sh62w45aheseueseqe5ul'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1etxtq3v4chzn7xrah3w6ukkxy7vlc889n5ervgxz425msar6ajzs869wa3'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom14sa4u42n2a8kmlvj3qcergjhy6g9ps06rzeth94f2y6grlat6u6spmw5ha'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1ypk8p7c82whs9xdja6ku7q6slzj8kvfwkgxnyeuevhtf03fteylq66uv02'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1l6ut7ymdzhf38wldp0eu6ccjawgvzku69kmjl6ddjqpcm9f62gkqufluv3'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1qg5ttwx6ylpphgc3rtu5j8sgjn0d4p2dv7q6kpw8d3lf8tkr6ahsedqr4h'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1lj48z799hq4hgzg6ppdzsq55h6cezfe0cmrnnv7cclkpw9qrvf9sq9wd75'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'BTC',
#       'contract': 'bostrom1387uc3z2zs3663d06f59vsn5ams2x6e33gqpghjkmhafjqsc9a3qdwrgss'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmWPSk41ZHrQ1mrhUeFgH2hcJ8rDXzXHzoPJLMvSJRry15',
#       'ticker': 'JUSD',
#       'contract': 'bostrom1hz3svgdhmv67lsqlduu0tcnd3f75c0xr0mu48l6ywuwlz43zssjqztrp7f'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmQj86rXfNxvWog5tUJ4NAm8Ebna7yAtmGXc7RjDr8bwjj',
#       'ticker': 'AFA',
#       'contract': 'bostrom1qfwnnm6z7zlgpk2ltwfh9hk8d4vwpu5h5nv2pqxwthve7htygzmsntvhwu'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmaqGSGT1tqLJoWTRj4qroaysAmcS6RiAbsQG9pTPaHAwK',
#       'ticker': 'LIINA',
#       'contract': 'bostrom14vjqp6cq9mr90wzmqxsa5erx70h4xy5eep0jynjqmlstupngtghqpk9kva'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'Qme8ohCqPM8yiGrazSeJoV3D3HJx3Ri1Xyzr9ChYZkQUmi',
#       'ticker': 'VTKN',
#       'contract': 'bostrom1hw7hhql6f25n49u9ju5vxhae3l9t9ck57xrnur24zxg0rvuky9mqatqvg3'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '2',
#       'logo': 'QmT9bNHyKjNDNWK3zmBSrxn3uVEXPvsrzo8d4DFmWTf1Wn',
#       'ticker': 'KLARI',
#       'contract': 'bostrom17s7emulfygjuk0xn906athk5e5efsdtumsat5n2nad7mtrg4xresu66g83'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'Qmdbcbpfft5NjS8d4L2nxpBrfQrrtNTCHa3WHqXnu2ix3b',
#       'ticker': 'AAAB',
#       'contract': 'bostrom14tccd5wwd6ygwtx67xdfpzz8xn8ysd3rkmkd3pj326l2v7asjr6q5cmkug'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbMsDAkD4Ag4MNQL1NKAoAAN8DYQMXEpwHRZjmxonFKTq',
#       'ticker': 'SHTKN',
#       'contract': 'bostrom1zvjnc08uy0zz43m0nlh9f5aetpa3amn6a034yqvmsgvzshk9cldsqf2n5c'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '2',
#       'logo': 'QmNob6bRzRs5dWtAGqiZxegpwxGfKE8y7B6yuE4B6sd2kP',
#       'ticker': 'PGNN',
#       'contract': 'bostrom1vm7slaygzkr3qllr8d4s6n4xq5wmvdauu3395lvkf53rhh6tgkhqrjg2xu'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom1r57m20afwdhkwy67520p8vzdchzecesmlmc8k8w2z7t3h9aevjvsts872g'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '2',
#       'logo': 'QmV2LYeBCCaRvvKzQXYjQSiDAPcCArqgV6n5XsCTLdPfdF',
#       'ticker': 'TEST',
#       'contract': 'bostrom1xl7dhgwggn43hy9q2dmul8hln5e9hzja48h7r4k0de4lachysq4s7hh996'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '2',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TEST',
#       'contract': 'bostrom1pv56ghmgnt9sv0ry6fg3rqf6wgfnckksppltamwsdnd0e0e0kfms92ntpq'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TEST',
#       'contract': 'bostrom10t2y7f9m0twpsrz3kvfp55nlgzc86kace2se3uarkv380h3pk6qqexed44'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TEST',
#       'contract': 'bostrom12cvr4t3rqdl5d90p3qsdq2ej8dte5k4gdsxs6uccmzq4h2307nfq8pfa6j'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '4',
#       'logo': 'QmXB4vxS6g2FEmLjLCKk4kPi5bGxNoxzjqyXDGE2urjhHZ',
#       'ticker': 'GUT',
#       'contract': 'bostrom1pnzsahkfp9h3gtwkuhsps6xjm5wz5885hpl27atvaqdn7e23vrdqhcafy5'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmNdionZXUHWu2538zTQtQBzMMM5mbkALcE5FJNtV3hwSv',
#       'ticker': 'AMJ',
#       'contract': 'bostrom1pcmlq5cwmy9lxfhynnuhd0r2djm2xn3ff2xc6njncs8sxzlgle3sa2ucvv'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmeWfo42txJWfG9pj6aJSYA2Z8yAbumAVGFTGtUnbRW4sy',
#       'ticker': 'OKB',
#       'contract': 'bostrom1n08lr7w2tkpd8m79hmt3ex7076awk77qysdzlg70a35agwzznwzqrkrpez'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '4',
#       'logo': 'QmUuCpp67XgtLtaFgiTB546ZVjog3MGwBYFzK6t1Ggatgr',
#       'ticker': 'ATH',
#       'contract': 'bostrom1yu6t6vxry85yt052uegp8dyrkk84lxsvact60sj25ns4380g03gspx0jke'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmeoVXbXb7oV6dvyNk7zoofot7DRFzQZUxNbMJZNMDHMU9',
#       'ticker': 'JNB',
#       'contract': 'bostrom1xq7yffwchsu2ldw3lukgzcncryva7wt35gv9cr59wt6ts2ktknwqe20r4y'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmeoVXbXb7oV6dvyNk7zoofot7DRFzQZUxNbMJZNMDHMU9',
#       'ticker': 'SNS',
#       'contract': 'bostrom1fchxlkly99gqymnvpfdyqjw9xc2cx62yplvw3rcfl2t5wurj3j9ssempqf'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmeGCgXxCsz7NQ3to1eg2U4ibbawxyQTd6XgchfTDczREL',
#       'ticker': 'HEH',
#       'contract': 'bostrom15pqspe0lcyeztwmk232vkwqgpklku5t74du00827l44p4vxnal7qp8xe27'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAAA',
#       'contract': 'bostrom1kjmzvl2us872qverxre5shu747zsx4rh0xp58l4hx838ck7zcp0qs7uu30'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmVRywVV8ZpyRiz9yLCCMufqidSJrducW71vv63BQMB8zn',
#       'ticker': 'ABRKD',
#       'contract': 'bostrom1nreyn9v8hwkmw254cszhsvpzn2a4x8pcjmnv736s53q5pvznm0vq28hgek'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'ASDS',
#       'contract': 'bostrom17s8kkfm5lf8lacz704f4fjmfxzuvyqd8cksakrlhnrass4yacvxqhu673c'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'ASDS',
#       'contract': 'bostrom1w9udhqtvuefwfmx7af9qe5jjhmrjk4p7ezxm6py08puykgen6uhqyhpwsu'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmXyGsQAthzmBRjW87xrqADWFfHJYbcFjD4QA5aXHPTo9T',
#       'ticker': 'CYBC',
#       'contract': 'bostrom1l2fvuecjpakxxh6k0mhpxzeln2veqpjs7znm8mfavuwx506v0qnsxr7sar'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAABD',
#       'contract': 'bostrom1nzvd5njkc0gqdezgzzqw00tu056rgxgwaqgq25g9ku0y5au3nwmqhh4kaz'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmefkBJpLP8nVZknst77mLFznRCgvn1UnSMAU1zfXgJe6d',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1cv5er0wsla3u33w6rkn7ckxpn88huqh9aw0xpu0pagksege7v7nszs7c9d'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmefkBJpLP8nVZknst77mLFznRCgvn1UnSMAU1zfXgJe6d',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1fka7t9avjmx7yphqxn3lzy3880tgcc0wu23xwfwxe5e5y3lkmzfqudn473'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmefkBJpLP8nVZknst77mLFznRCgvn1UnSMAU1zfXgJe6d',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1ddstvl38skwpm284gfaqukn3e8c4mlf26mssy5hppeq6ar2nnw0serdun8'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'GHY',
#       'contract': 'bostrom1hdnu502uecmddk9w48kxvekgp43mjdpr3mza9kj2tfvjpgef5grscmxg4l'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '8',
#       'logo': 'QmZSmiNV3Ro7kZbgvGo8MTuZ8xgyxzMRyUwFKYCSLCLHdz',
#       'ticker': 'BTC',
#       'contract': 'bostrom1qnynuzvl2a5nzxtrhjhw20h0mf7u6tarcuqveqd0qzp7322n5rqs9wnx3q'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AUT',
#       'contract': 'bostrom19377ce3k2893s98xp58vg0jtgtvj5qv405y36l4wf4z2xhnjwh6shrq80l'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'CBP',
#       'contract': 'bostrom1r8td9cjggx9f5ek2gzfh34kguxuz5j9rfjemamvjw2he2y84t3xqn47qsf'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'OBL',
#       'contract': 'bostrom18ckrreffz9jwmkw84axsvncexfqt7gpgckskk0yy0vzwm9huqkyqzshjgs'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'VGN',
#       'contract': 'bostrom10v8m3lglw4vat5g3w4xj7ven7puxudnqkjwwaf9nh3alukxpmh3qktyrc8'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NBDC',
#       'contract': 'bostrom1l0z6d7wlwpwequtenwt8pd44685jyhqys6jdnp8xa8ektn0un4zs93dmfg'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'GDVP',
#       'contract': 'bostrom18p7lhcxl3ac85ke52u4h7mmzkv5pk5jl6lpgk2sp73a0cw3u0c5qszd0qv'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'KPWR',
#       'contract': 'bostrom1x9zrl4gvf0780rcxnv9fjx2h52jg6zxpxzgq6lhhjqyrg0ue4dyq3pmggq'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'UPD',
#       'contract': 'bostrom156x86uprzaj04v7qwnpl8djj5jws3gn73jz08qkydmkd0c0lp6gqp254ht'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'UPDI',
#       'contract': 'bostrom18hu00pwvd8kq0cgzk03l2nmp8rr0h5gp6tektz6qazwfapqsl4cqk4pc7q'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'UPDH',
#       'contract': 'bostrom17ptevgk0rr06mctweh66mq54ywq62yjllwh5sg0e0f3mr5sta0zqk9kw52'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAAA',
#       'contract': 'bostrom1jpdjyc3c973frxkjkmvgr5ececzf9qslzrunxd2xkstem8zr338sq0t7yj'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TST',
#       'contract': 'bostrom18dhyf7sdkjpmgu4jg6fmf4d6cyj9lez6c2cs5lvprkmyctfrtnzqh9j8t3'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PGNT',
#       'contract': 'bostrom100pmxfny54wktum5jklg9vme7d5pe44h7va6uw4smccte6wkfausnn4x9z'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'WSLPT',
#       'contract': 'bostrom1379zqdvfjcv3sd0w2zhkvtlc0au5yy4htad6fec92c09rpptd6lsek9yrx'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'NTN',
#       'contract': 'bostrom17sxcqvz6vh7nqsj5kantv5x86pj0wc4slh50j9ek60pyjg5tym2qd6rnu7'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'WSLPT',
#       'contract': 'bostrom1m6s6l9uhstdnhnetcs29da4enf8qj0nk4rdvl8gxhl0m8pudtfjstu67wq'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'WSLPT',
#       'contract': 'bostrom1zjw8px94wuqcfa69z2py6x8ax29up26zmk3suqq6d6vvweppffdqnsvfw5'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'WSLPT',
#       'contract': 'bostrom1aqjn8sha92zyqd27d4gw8lnjgmgt24v3ytwm2f9j9rza7pfuku4svfqjh4'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'WSLPT',
#       'contract': 'bostrom1fdtlnwuqwp38tq5ky5g3xfkkafexa4e8q4qy90jxe2vmtl8n56ksq3qljm'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SCSI',
#       'contract': 'bostrom1s82s62c3q5cnjfhcqmvthjd58t6jetxmf8rxp9xmqmyy05fu2quseeqatj'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1w23vphvjp0qm4jhche00905admg69pgry74vv88d09c4k7g67n3q9e3nms'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TTT',
#       'contract': 'bostrom1hje6ecs6u683ypnzu8l5d4jsxq4dy96s0m6ezps9uwcuwl30hfuqy4x65j'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SSS',
#       'contract': 'bostrom1mujpjkwhut9yjw4xueyugc02evfv46y0dtmnz4lh8xxkkdapym9ss96xz0'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SSS',
#       'contract': 'bostrom1exfwrk0t57hn8ffcwjdnh6rkp7mq0n39duhaugttf69znaeq3w3s9wmc4f'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SSSS',
#       'contract': 'bostrom19vxp8vq8qm368dr026qxh8v82satwaf79y235lfv6wmgpwxx8dtscamrcj'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAAA',
#       'contract': 'bostrom1y2s9zx3lvyhdlqx6mvaq0xe8ctl34rwuqnntjw6meerln6dz7fjsxye5r7'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AABC',
#       'contract': 'bostrom168ctmpyppk90d34p3jjy658zf5a5l3w8wk35wht6ccqj4mr0yv8sdwagq0'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AABCA',
#       'contract': 'bostrom1s84uvkzuz7tlyykp587aynn8xr0m6t5r64lz6pkfyzyrhzaezhrss8uvkl'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AACC',
#       'contract': 'bostrom1exdh6lv0l5cukjg2gmrymy9cpyunughewwx8d8g93sqfnzy7mudslyawvk'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAS',
#       'contract': 'bostrom1lvhdnjcq05czd38hy25fzk80cn03hhxens4e2am9468rmpzc82mshp9hv8'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmRbEoWS3jPxYkb2yzHv7Sio3tr3sU1oQArmhBAGuXaVZA',
#       'ticker': 'TTC',
#       'contract': 'bostrom13xww866f545ackl0004tm94jdh5y7hht5rjnpejktyw4nqkvrxtsuxfrq6'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'FFF',
#       'contract': 'bostrom1w9pht45shvg9p0lpvs37hug0jggplaet56gz44vx4lcw3fuamfcsns2h3d'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'FFF',
#       'contract': 'bostrom1phzfjt6x25u29grhesrkw4enwytynufdptk87cauvwy5aw4h5uxsqhcle2'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1j9a5fr6rcfq2kuew5n48cc6l6j2wd2jzrw8eea0aj8qypvex02dqeydd2n'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'ZZZ',
#       'contract': 'bostrom1taerpmv0tzdrnls7z567khds88fwfpdaeeg7s0wkel9zjap7gnes5rzywn'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PPP',
#       'contract': 'bostrom1gje2etr7mwfefd77lfrd4a9avvru8pkmzypu6d4nu0jxrjkxzdqsqnyq7e'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'BOOOO',
#       'contract': 'bostrom13v589qn2n2h7aqf3uzfa2qglf2cqgxl8t4ntfs6u66rzqfy9ln6szelnv7'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAA',
#       'contract': 'bostrom1quce89l8clsn8s5tmq5sylg370h58xfnkwadx72crjv90jmetp4sf4l37n'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAC',
#       'contract': 'bostrom1ktsva89ss04d0qwd6q60uc77w0ma5gkwd7ufflhhpmeam738y0eqhylyg2'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PGNT',
#       'contract': 'bostrom14rs8gv8phhxtwjad096swkdd8sfg2s7c2xe55ses50spkwr585nsenkzh0'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'TTTT',
#       'contract': 'bostrom1ukhxlrtje0dt2n7k54m8l83rxjrta7fqwvzzhapgzafwzt38u8pqg3qket'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'PGNT',
#       'contract': 'bostrom1zkjgu5pdsswczdjg87v87wtyhavavnq99jnyngmn83x58kly49vsln9mkn'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'SSS',
#       'contract': 'bostrom1fe9ldmu9qy3pyx28esrn0g088jeqvs6jchat2m900fvnxt2wljvsac56ht'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'DDD',
#       'contract': 'bostrom1kfem4ue4qn9p689ldye9t4seh077lz3ztr4zhjadxptjsaujxk5spqssdw'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'EEE',
#       'contract': 'bostrom1g6u7zm0gykqk7aklasatgtrld5heyfqmydvvu5ne6h2lq9zx69wswdm79m'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'ZZZ',
#       'contract': 'bostrom1vvgyl5xndpqn3vgymjlwklv7kjmk3zwzf6r6ukakqk5qnzksktds9a58un'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'ZZZ',
#       'contract': 'bostrom1jmechmr7w6kwqu8jcy5973rtllxgttyetarys60rtsu0g675mkjsuen7fn'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'Qma9xsv2iWdecCQtrkQoiXwQhd7dWvJ6175kjmjhgSKfcQ',
#       'ticker': 'TTT',
#       'contract': 'bostrom1s5g4rehkansq4pamj42usczezqkchjke4j2kk7qm3a5vkejz0xuqy57rc4'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '0',
#       'logo': 'QmefkBJpLP8nVZknst77mLFznRCgvn1UnSMAU1zfXgJe6d',
#       'ticker': 'ABC',
#       'contract': 'bostrom1seeld9pqq0nxp3yt3wded4jf476y8vz77qmjj5zf8gwz3y59qu5s4af596'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '10',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'AAAC',
#       'contract': 'bostrom10stecvwvxzkh3ah7y6j0kcwe3chmrg37zevjgjpz06sqx8vd5d6qeh0u08'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmRbEoWS3jPxYkb2yzHv7Sio3tr3sU1oQArmhBAGuXaVZA',
#       'ticker': 'WGUT',
#       'contract': 'bostrom1w4dff5myjyzymk8tkpjrzj6gnv352hcdpt2dszweqnff927a9xmq4qnw7u'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'},
#    {'sender': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t',
#     'contract': 'bostrom1uay5ex5z547dw7mhw4puwcg998zu474czftlv5s9qpmywl2umaus4vd6x3',
#     'msg': {'CreateEntry': {'chain_id': 'bostrom',
#       'channel_id': '',
#       'decimals': '6',
#       'logo': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH',
#       'ticker': 'COOL',
#       'contract': 'bostrom1nwm9pjmfgmxgc4euyfps05p9pfde8vd4sm8pavy93eu9xquz27dsgyxtml'}},
#     'funds': [],
#     '@type': '/cosmwasm.wasm.v1.MsgExecuteContract'}],
#   'memo': 'upload cw20 token list',
#   'timeout_height': '0'},
#  'auth_info': {'signer_infos': [],
#   'fee': {'gas_limit': '24000000',
#    'amount': [{'denom': 'boot', 'amount': '0'}],
#    'payer': '',
#    'granter': ''}},
#  'signatures': []}
